# %%
import pandas as pd

# %%
df_nf_unique = pd.read_csv('notasFiscais/df_nf_unique.csv')
df_nf_unique
# Out:
# /tmp/ipykernel_54066/1538487853.py:1: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_nf_unique = pd.read_csv('notasFiscais/df_nf_unique.csv')
#                ID  MODELO  SERIE  NUMERO_NOTA_FISCAL             DATA_EMISSAO  \
# 0              10      55     21               37005  2022-01-01 00:00:00.000
# 1              14      55     21               37005  2022-01-01 00:00:00.000
# 2              16      55     21               37005  2022-01-01 00:00:00.000
# 3              53      55      1             2148830  2022-01-01 00:00:00.000
# 4              88      55      1               25085  2022-01-01 00:00:00.000
# ...           ...     ...    ...                 ...                      ...
# 2248616  75679419      55     10               12741  2023-07-31 00:00:00.000
# 2248617  75679436      55     10               12741  2023-07-31 00:00:00.000
# ...

# %%
df_unique_index_nf = pd.read_csv('df_unique_index_nf.csv')
df_unique_index_nf
# Out:
#          Unnamed: 0.1  Unnamed: 0        ID  MODELO  SERIE  \
# 0                   0           0  49537821      55      1
# 1                   1           1  53886647      55      1
# 2                   2           2  38357115      55      1
# 3                   3           3  67282171      55      8
# 4                   4           4  33006554      55      1
# ...               ...         ...       ...     ...    ...
# 1124634       1124684     1124684  75293628      55      1
# 1124635       1124685     1124685  75324339      55      1
# 1124636       1124686     1124686  75501409      55      1
# 1124637       1124687     1124687  75561037      55      5
# 1124638       1124688     1124688  75663635      55      1
#
#          NUMERO_NOTA_FISCAL             DATA_EMISSAO  CNPJ_CPF_EMITENTE  \
# 0                     13870  2023-01-18 00:00:00.000     25546178000163
# 1                    109951  2023-02-22 00:00:00.000      5677144000109
# ...

# %%
df_unique_index_nf['CODIGO_BARRA'].value_counts()
# Out:
# CODIGO_BARRA
# 7891033481309    184
# 7891033480623    179
# 7891033826896    177
# 7891033301928    176
# 7891033826889    174
#                 ...
# 7893986588364      1
# 7898469641246      1
# 7909636681658      1
# 7899728201232      1
# 7899658421137      1
# Name: count, Length: 831981, dtype: int64

# %%
df_unique_index_nf

# %%
# dv_relev_sample.to_csv('queries_relv.csv')
dv_relev_sample = pd.read_csv('queries_relv.csv')
cod_b = dv_relev_sample['CODIGO_BARRA']
cod_b = cod_b.tolist()
cod_b
# Out:
# [7898062608721,
#  7896380173433,
#  7891000261026,
#  7891260382752,
#  7891117007128,
#  7896040704625,
#  7891435051834,
#  7898133136450,
#  7897801300841,
#  7897801301763,
#  7891040113491,
#  7896079587329,
#  7500435157513,
#  7895500761178,
#  7891033716418,
#  7898526969856,
#  7898932213895,
#  7898610372555,
#  7891019170609,
#  7898075640053,
#  7908324400298,
#  7891242161818,
#  7896011102610,
#  7899381693962,
#  7891521359127,
#  7893371000259,
#  7891117003748,
#  7899952304273,
#  7891033773572,
#  7891321333174,
#  7500435169370,
#  7891317439002,
#  7898436366844,
#  7894325109585,
#  7896112401926,
#  7891150036390,
#  4005808335435,
#  7896004720838,
#  7804540226387,
#  7898330152109,
#  7891696009551,
#  4013790009432,
#  7898360914173,
#  7891150071537,
#  7891117003922,
#  7908324400120,
#  7899065804998,
#  789109550004,
#  7897016830133,
#  7891035800245]

# %%
descr_r = df_unique_index_nf[df_unique_index_nf['CODIGO_BARRA'] == 7896040704625]
descr_r
# Out:
#          Unnamed: 0.1  Unnamed: 0        ID  MODELO  SERIE  \
# 1123976       1123980     1123980   3147343      55      1
# 1124043       1124049     1124049  13576023      55      1
# 1124094       1124104     1124104  19446495      55      1
# 1124119       1124130     1124130  21604564      55      1
# 1124164       1124178     1124178  26797772      55      2
# 1124175       1124189     1124189  28856580      55    300
# 1124220       1124234     1124234  32681262      55     10
# 1124223       1124237     1124237  32882563      55      1
# 1124228       1124242     1124242  33164086      55      1
# 1124236       1124252     1124252  33642493      55      1
# 1124244       1124260     1124260  33932472      55     21
# 1124250       1124268     1124268  34594427      55      1
# 1124269       1124290     1124290  35738412      55      1
# 1124278       1124299     1124299  36422551      55      1
# 1124287       1124310     1124310  36642791      55      1
# ...

# %%
for i in cod_b:
    tam = df_unique_index_nf[df_unique_index_nf['CODIGO_BARRA'] == i]
    print(i, len(tam))
# Out:
# 7898062608721 12
# 7896380173433 12
# 7891000261026 21
# 7891260382752 22
# 7891117007128 32
# 7896040704625 47
# 7891435051834 12
# 7898133136450 14
# 7897801300841 26
# 7897801301763 16
# 7891040113491 4
# 7896079587329 6
# 7500435157513 7
# 7895500761178 7
# 7891033716418 47
# 7898526969856 4
# 7898932213895 4
# 7898610372555 5
# 7891019170609 10
# 7898075640053 13
# 7908324400298 11
# 7891242161818 11
# 7896011102610 13
# 7899381693962 20
# 7891521359127 4
# 7893371000259 17
# 7891117003748 12
# 7899952304273 11
# 7891033773572 41
# 7891321333174 11
# 7500435169370 4
# 7891317439002 7
# 7898436366844 6
# 7894325109585 4
# 7896112401926 5
# 7891150036390 13
# 4005808335435 18
# 7896004720838 19
# 7804540226387 7
# 7898330152109 10
# 7891696009551 10
# 4013790009432 9
# 7898360914173 10
# 7891150071537 8
# 7891117003922 24
# 7908324400120 43
# 7899065804998 5
# 789109550004 4
# 7897016830133 6
# 7891035800245 23

# %%
df_test_relv = df_nf_unique[df_nf_unique['CODIGO_BARRA'].isin(nf_codigos_comuns)]
df_test_relv

# %%
df_unique_index_nf['CODIGO_BARRA'].value_counts()
# Out:
# CODIGO_BARRA
# 7891033481309    184
# 7891033480623    179
# 7891033826896    177
# 7891033301928    176
# 7891033826889    174
#                 ...
# 7893986588364      1
# 7898469641246      1
# 7909636681658      1
# 7899728201232      1
# 7899658421137      1
# Name: count, Length: 831981, dtype: int64

# %%
df_index_catmat = pd.read_csv('df_index_catmat_resample.csv')
# Out:
# /tmp/ipykernel_130596/2121365791.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_index_catmat = pd.read_csv('df_index_catmat_resample.csv')

# %%
# df_unique_index_nf[df_unique_index_nf['ID'].isin([19471168, 63303202, 32421960, 15474061, 34945710, 42994452, 29926389, 51915257, 58420699, 41078396, 33985406, 72817119])]
df_unique_index_nf[df_unique_index_nf['ID'].isin([26393348, 56469138, 141465, 48361885, 17192740, 48780585, 10702892, 1256239, 21855923, 22089395, 43052347, 22619836, 24889538, 22281156, 39901511, 5481933, 69741012, 8870616, 30152801, 20896228, 36132974, 554489, 9765116])]
# df_unique_index_nf[df_unique_index_nf['CODIGO_BARRA'] == 7899307514173]
# 26393348, 56469138, 141465, 48361885, 17192740, 48780585, 10702892, 1256239, 21855923, 22089395, 43052347, 22619836, 24889538, 22281156, 39901511, 5481933, 69741012, 8870616, 30152801, 20896228, 36132974, 554489, 9765116
# df_unique_index_nf[df_unique_index_nf['ID'].isin([50146826, 40368151, 34393625, 10700833, 33055269, 61173816, 36867645, 69460545, 56621122, 71752772, 69460549, 43265604, 69460556, 69460561, 34142802, 72814675, 36392019, 69460565, 7943766, 69460567, 69460563, 69460570, 69460571, 69460572, 34740832, 41507937, 37566078, 64655507, 565395, 72814743, 50133147, 49521831, 21316775, 51286192, 54996163, 54822085, 32873678, 22089425, 34555611, 33148639, 47516383, 63333108, 50269941, 50057975, 33805570, 57518338, 41338638, 34676000, 32708389, 43668275, 33388854, 1803069, 53035838, 19471168, 56545094, 51822920, 37942106, 37942111, 37942122, 37942126, 37942127, 18287993, 33985406, 67808644, 75124103, 67872647, 60739465, 43648411, 40368122, 36935601, 34646450, 36935603, 57951156, 67218866, 39188407, 44152247, 36935615, 50030022, 45175242, 74619340, 1353167, 71202260, 58420699, 21407197, 32721886, 6384607, 66888670, 20646882, 34399718, 51754471, 43240430, 17994735, 69270510, 29926389, 37175285, 51915257, 38592506, 50106875, 35327484, 65228287])]
# lista = []
# df_unique_index_nf[df_unique_index_nf['ID'].isin([54822085, 41338638, 72814675, 29926389, 40368151, 61173816, 51915257, 58420699, 72814743, 33985406])]

exp = df_unique_index_nf[df_unique_index_nf['ID'].isin([68075008, 32882563, 28856580, 45004548, 59658499, 74122760, 45668365, 43881747, 36422551, 55159064, 39147162, 69178268, 42713630, 57277220, 35738412, 38239533, 32681262, 65682224, 45219634, 56325682, 33164086, 42210615, 33932472, 50532153, 55507639, 51199292, 43097790, 47008635, 38106437, 41860806, 75212871, 26797772, 3147343, 59981264, 21604564, 65905749, 13576023, 19446495, 69911269, 74796005, 36642791, 45198567, 68586734, 37403763, 34594427, 33642493, 44823550])]
exp['DESCRICAO_PRODUTO']

# 7899065804998
exp = df_unique_index_nf[df_unique_index_nf['CODIGO_BARRA'] == 789109550004]
exp['DESCRICAO_PRODUTO']
# Out:
# 1123965            LENTE P/SOLDA RET.PRETA TON-10 CARBOGRAFITE
# 1123987    LENTE P/ MASCARA DE SOLDA 51X108 TON 10 - CARBOGRAF
# 1124253                LENTE P/ MASCARA DE SOLDA 51X108 TON 10
# 1124292      LENTE CARBOGRAFITE MASCARA DE SOLDA 51X108 TON 10
# Name: DESCRICAO_PRODUTO, dtype: object

# %%
exp = df_index_catmat[df_index_catmat['ID_MATERIAL'].isin([588887, 588958, 588960, 588961, 557226, 479918, 479960, 479961, 479962, 479963, 479964, 479965, 479966, 479967, 479968, 546016, 520999, 538442, 543060, 543061, 543062, 543063, 543064, 543065, 543066, 543067, 543068, 543069, 543070, 543071, 543072, 543074, 543075, 543076, 543077, 543079, 543080, 543081, 543082, 543083, 543084, 543085, 543086, 543087, 543088, 543089, 543090, 543091, 543092, 543093, 543094, 543095, 543096, 543097, 543098, 543099, 543100, 543101, 543102, 543103, 543104, 543105, 543106, 543107, 543108, 543109, 543110, 543111, 543112, 543113, 543114, 543115, 543116, 543117, 543118, 543119, 543120, 543121, 543122, 543123, 543124, 543125, 543126, 543127, 543128, 543129, 543130, 543131, 543132, 571897])]
exp = exp['MATERIAL_TEXT']
exp.to_csv('exp')

# %%
42084871, 23816203, 27501579, 32545293, 27612688, 45465620, 52596252, 74975778, 670246, 63948841, 56325682, 45860920, 61801529, 54961215, 9559106, 35656267, 32896603, 13007964, 75314790, 34427497, 49330285, 36077166, 28491378, 71523445, 17150593, 25411204, 70539908, 68123781, 5616775, 51242137, 5616802, 10378919, 650928, 60992181, 57104065, 72660164, 35369668, 6579400, 36329684, 35401431, 41995492, 39821555, 32665850, 34944266, 7773451, 55567116, 41336589, 35694865, 33896213, 33768226, 39798052, 41336614, 62543659, 39105840, 51199283, 59141430, 42398008, 53388601, 37108541, 49351499, 35636046, 34944851, 57037140, 41077080, 62159192, 36470114, 49365859, 34217848, 29395324, 35522430, 64101758, 33407366, 36499862, 34766233, 36182943, 63914402, 62673826, 31818151, 52614568, 44643244, 29550514, 58594228, 29550517, 32548796, 49983421, 53072830, 66458047, 33904064, 30211008, 66849736, 54825930, 45789645, 59981264, 74796005, 36932079, 22461939, 41080308, 32545270, 8258040, 32545278

# %%
df_unique_index_nf[df_unique_index_nf['CODIGO_BARRA'] == 7891321333174]
# Out:
#          Unnamed: 0.1  Unnamed: 0        ID  MODELO  SERIE  \
# 1124087       1124096     1124096  18934689      55      1
# 1124227       1124241     1124241  33050035      55      1
# 1124238       1124254     1124254  33690610      55      1
# 1124281       1124302     1124302  36484408      55      1
# 1124296       1124322     1124322  37781396      55      1
# 1124337       1124367     1124367  41480101      55      1
# 1124390       1124421     1124421  45921786      55      1
# 1124397       1124429     1124429  46285835      55      1
# 1124449       1124483     1124483  51223766      55      1
# 1124456       1124490     1124490  51801794      55      1
# 1124483       1124519     1124519  55197933      55      1
#
#          NUMERO_NOTA_FISCAL             DATA_EMISSAO  CNPJ_CPF_EMITENTE  \
# 1124087              778830  2022-06-06 00:00:00.000     47064738000186
# 1124227              786010  2022-09-19 00:00:00.000     47064738000186
# ...

# %%
codigos_barra_repetidos = df_unique_index_nf['CODIGO_BARRA'].value_counts()
codigos_barra_repetidos_menos_de_2 = codigos_barra_repetidos[codigos_barra_repetidos < 3]
codigos_barra_repetidos_menos_de_2
# Out:
# CODIGO_BARRA
# 7896488613268    2
# 7898594832083    2
# 8005610657387    2
# 7898615775221    2
# 7898901903352    2
#                 ..
# 7893986588364    1
# 7898469641246    1
# 7909636681658    1
# 7899728201232    1
# 7899658421137    1
# Name: count, Length: 780264, dtype: int64

# %%
df_selecionadas = df_unique_index_nf[df_unique_index_nf['CODIGO_BARRA'].isin(codigos_barra_repetidos_menos_de_2.index)]
df_selecionadas
# Out:
#          Unnamed: 0.1  Unnamed: 0        ID  MODELO  SERIE  \
# 0                   0           0  49537821      55      1
# 1                   1           1  53886647      55      1
# 2                   2           2  38357115      55      1
# 4                   4           4  33006554      55      1
# 6                   6           6  33683578      55      2
# ...               ...         ...       ...     ...    ...
# 1123927       1123927     1123927  43402563      55      1
# 1123928       1123928     1123928  55025022      55      3
# 1123929       1123929     1123929  57188744      55      1
# 1123930       1123930     1123930  37013181      55      1
# 1123931       1123931     1123931  37211721      55      1
#
#          NUMERO_NOTA_FISCAL             DATA_EMISSAO  CNPJ_CPF_EMITENTE  \
# 0                     13870  2023-01-18 00:00:00.000     25546178000163
# 1                    109951  2023-02-22 00:00:00.000      5677144000109
# ...

# %%
df_sample = df_selecionadas.sample(50)
df_sample
# Out:
#          Unnamed: 0.1  Unnamed: 0        ID  MODELO  SERIE  \
# 115465         115465      115465  39008829      55      1
# 933818         933818      933818  39448655      55      1
# 838472         838472      838472  64224957      55      1
# 223750         223750      223750  61582508      55      6
# 786911         786911      786911  71031899      55      1
# 308442         308442      308442  39471663      55      3
# 1018764       1018764     1018764  48372547      55     16
# 627089         627089      627089  70856539      55      1
# 20687           20687       20687  57836013      55      1
# 659925         659925      659925  39155894      55      1
# 838593         838593      838593  13441241      55      1
# 472103         472103      472103  47333378      55      5
# 671768         671768      671768  55527592      55      1
# 182751         182751      182751  52361497      55      1
# 346931         346931      346931  65943255      55      2
# ...

# %%
descr = df_sample['DESCRICAO_PRODUTO']
descr.tolist()
# Out:
# ['TESOURA P/CORTAR PELO DO NARIZ',
#  'PRATO N 4 - PRETO',
#  'CELEBRE DES COL MASC AGORA PRM 10ml',
#  'MOLETOM LOGO ADIDAS COM CAPUZ',
#  'CALCA 103759 OCRE (16-1148TCX) 38',
#  'BQ ROSA X 5 CETIM LX BRANCO',
#  'ARRUELA PLASTICA DIA.55MM',
#  'GENTLECATH GLIDE MALE CH10 (1X30PK) EUR',
#  'SACOLA PAPEL18X29 P PASCOA DOCURA',
#  'BLUSA REGATA Cor CA46C Tam P',
#  'VENZER 32MG C/30CP (LIB)',
#  'BICO QUADRADO HOMEM JOTA PE 77700 39',
#  'LOCAO DE LIMPEZA PARA AXILAS 200ML - MYDE HIPO',
#  'VENOSAN LEGLINE AD 15-23 P PE FECHADO PRETO PRETO  Lote:314187 Ean :7898360912292',
#  'SANDALIA NAPA TATHI NUVEM BRILHO 3060.19_2 38',
#  'LYSOL, Desinfetante Liquido Lysol Pro Line Pureza do Algodao 5L',
#  'OPPNUS CALCA MASCULINA REGULAR SLIM CACIO UNICA 36',
#  'MAN-W950/26 - FILTRO LUBRIFICANTE BLINDADO',
#  'PETISCO NATURAL CRISP CHIPS CARNE COM BANANA-100 G',
#  'LITTMANN CARD IV 6204 SK P-C 3M LITTMANN CARD IV SK P-C',
#  'Acelerador Punho Rapido Red Dragon Universal',
# ...

# %%
queries_result_relv = pd.read_csv('queries_result_relv.csv')
queries_result_relv['result_query']
# Out:
# 0     {"took":5,"timed_out":false,"_shards":{"total"...
# 1     {"took":72,"timed_out":false,"_shards":{"total...
# 2     {"took":1,"timed_out":false,"_shards":{"total"...
# 3     {"took":75,"timed_out":false,"_shards":{"total...
# 4     {"took":1,"timed_out":false,"_shards":{"total"...
#                             ...
# 95    {"took":73,"timed_out":false,"_shards":{"total...
# 96    {"took":1,"timed_out":false,"_shards":{"total"...
# 97    {"took":77,"timed_out":false,"_shards":{"total...
# 98    {"took":1,"timed_out":false,"_shards":{"total"...
# 99    {"took":74,"timed_out":false,"_shards":{"total...
# Name: result_query, Length: 100, dtype: object

# %%
df_materiais = pd.read_csv('df_materiais.csv')
df_materiais
# Out:
#         Unnamed: 0  ID_MATERIAL TIPO  CODIGO_MATERIAL ITEM_SUSPENSO  \
# 0                0       431550    M           600581             N
# 1                1       431551    M           600580             N
# 2                2       431552    M           600579             N
# 3                3       431553    M           600578             N
# 4                4       431554    M           600576             N
# ...            ...          ...  ...              ...           ...
# 253861      253861       683446    M           377520             S
# 253862      253862       683447    M           377519             S
# 253863      253863       683780    M           612103             N
# 253864      253864       683781    M           229763             N
# 253865      253865       685185    M           332382             N
#
#        MATERIAL_SUSTENTAVEL  CODIGO_CLASSE  \
# 0                         N           5905
# 1                         N           5905
# ...

# %%
sample_catmat
# Out:
#     Unnamed: 0  ID_MATERIAL  \
# 0            0       543078
# 1            1       549581
# 2            2       550417
# 3            3       614992
# 4            4       478509
# 5            5       507527
# 6            6       497941
# 7            7       593021
# 8            8       542748
# 9            9       634100
# 10          10       513478
# 11          11       564630
# 12          12       476435
# 13          13       594908
# 14          14       480052
# 15          15       498742
# 16          16       484867
# 17          17       584553
# 18          18       676173
# 19          19       507553
# 20          20       560263
# 21          21       497966
# 22          22       539951
# 23          23       497197
# 24          24       667000
# 25          25       581205
# 26          26       543073
# 27          27       600923
# 28          28       556754
# 29          29       665380
# 30          30       538718
# 31          31       476635
# ...

# %%
sample_catmat = pd.read_csv('sample_catmat.csv')
id_mat = sample_catmat['ID_MATERIAL']
id_mat_df = df_materiais[df_materiais['ID_MATERIAL'].isin(id_mat)]
id_mat_df.drop_duplicates(['DESCRICAO_CLASSE'], inplace=True)
# Out:
# NOME_MATERIAL
# Aparelho Fac-Símile                                2
# Alvo De Tiro                                       2
# Calculadora Eletrônica                             1
# Revista                                            1
# Grafite                                            1
# Guarita                                            1
# Incinerador - Peca / Acessorio                     1
# Lanterna Não Elétrica                              1
# Mancal Especial Sob Encomenda                      1
# Máquina Ilhoseira                                  1
# Monovia                                            1
# Moto-Esmeril                                       1
# Retroescavadeira                                   1
# Seda Artificial ( Rayon )                          1
# Forno Industrial                                   1
# Tala Fixacao Trilho Ferrovia                       1
# Tubo De Vidro                                      1
# ...

# %%
df_materiais
# Out:
#         Unnamed: 0  ID_MATERIAL TIPO  CODIGO_MATERIAL ITEM_SUSPENSO  \
# 0                0       431550    M           600581             N
# 1                1       431551    M           600580             N
# 2                2       431552    M           600579             N
# 3                3       431553    M           600578             N
# 4                4       431554    M           600576             N
# ...            ...          ...  ...              ...           ...
# 253861      253861       683446    M           377520             S
# 253862      253862       683447    M           377519             S
# 253863      253863       683780    M           612103             N
# 253864      253864       683781    M           229763             N
# 253865      253865       685185    M           332382             N
#
#        MATERIAL_SUSTENTAVEL  CODIGO_CLASSE  \
# 0                         N           5905
# 1                         N           5905
# ...

# %%
sample_catmat = pd.read_csv('sample_catmat.csv')
id_mat = sample_catmat['ID_MATERIAL']
id_mat_df = df_materiais[df_materiais['ID_MATERIAL'].isin(id_mat)]
id_mat_df.drop_duplicates(['DESCRICAO_CLASSE'], inplace=True)
id_mat_df['DESCRICAO_CLASSE'].value_counts()
# Out:
# /tmp/ipykernel_7285/1405608436.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   id_mat_df.drop_duplicates(['DESCRICAO_CLASSE'], inplace=True)
# DESCRICAO_CLASSE
# MÁQUINAS DE CONTABILIDADE E DE CALCULAR                                                 1
# EQUIPAMENTO PARA REVELAÇÃO E ACABAMENTO FOTOGRÁFICO                                     1
# MAPAS, CARTAS E GLOBOS GEOGRÁFICOS                                                      1
# MINERAIS NATURAIS E SINTÉTICOS                                                          1
# MÁQUINAS PARA FUNDIÇÃO, EQUIPAMENTOS E  SUPRIMENTOS  CORRELATOS                         1
# EQUIPAMENTOS DE ILUMINAÇÃO NÃO ELÉTRICOS                                                1
# ...

# %%
classes_mt = id_mat_df['NOME_MATERIAL']
teseteee = df_materiais[df_materiais['NOME_MATERIAL'].isin(classes_mt)]
contagem_valores = teseteee['NOME_MATERIAL'].value_counts()
# Máquina Ilhoseira                                   4
# Revista                                             4
# Equipamento Radiação Nuclear - Peça / Acessório     4
# Álcool Anidro Combustível                           4
# Anemômetro                                          3
# Globo Geografico                                    3
# Estufa De Secagem De Pintura                        2
# Mancal Especial Sob Encomenda                       1
# Monovia                                             1
# Incinerador - Peca / Acessorio                      1
# Seda Artificial ( Rayon )                           1
# Tala Fixacao Trilho Ferrovia                        1
# Equipamento De Emendar Cabo                         1
# Armazem Pre - Fabricado                             1
a_ret = contagem_valores[(contagem_valores < 5) | (contagem_valores > 50)].index.tolist()
len(a_ret)
# a_ret = ['Filtro Linha', 'Aparelho Fac-Símile', 'Filmadora/Monitor Portátil', 'Calculadora Eletrônica',
#          'Garrafa', 'Tubo De Vidro', 'Cabo Aço' , 'Máquina Ilhoseira', 'Revista', 'Equipamento Radiação Nuclear - Peça / Acessório'
#          'Álcool Anidro Combustível', '', '', '', 'Anemômetro']
# Out:
# 21

# %%
id_mat_df = id_mat_df[~id_mat_df['NOME_MATERIAL'].isin(a_ret)]
id_classe = id_mat_df['DESCRICAO_CLASSE']
id_classe
# Out:
# 44256     EQUIPAMENTO PARA REVELAÇÃO E ACABAMENTO FOTOGR...
# 45352     EQUIPAMENTO DE TRATAMENTO TÉRMICO E NÃO TÉRMIC...
# 45401                EQUIPAMENTO PARA SOLDA A ARCO VOLTAICO
# 45410         EQUIPAMENTO PARA SOLDA A RESISTÊNCIA ELÉTRICA
# 45758              VEÍCULOS AUTOPROPULSIONADOS PARA ARMAZÉM
# 47287                         MÁQUINAS-FERRAMENTA PORTÁTEIS
# 48841                        EQUIPAMENTOS DIVERSOS DE SOLDA
# 67038              ACESSÓRIOS PARA TREINAMENTO DE ARMAMENTO
# 76714                                    BEBIDAS ALCOÓLICAS
# 107067                  VÁLVULAS ACIONADAS POR FORÇA MOTRIZ
# 119678                       MINERAIS NATURAIS E SINTÉTICOS
# 126738             EQUIPAMENTOS DE ILUMINAÇÃO NÃO ELÉTRICOS
# 134820    MÁQUINAS AUXILIARES PARA MODELAGEM E CORTE DE ...
# 151591    EQUIPAMENTOS PARA MOVIMENTAÇÃO E ESCAVAÇÃO DE ...
# 171698                                   REATORES NUCLEARES
# 205365    FILTROS DE AR E DE ÓLEO; ELEMENTOS FILTRANTES ...
# ...

# %% [markdown]
# # ESCOLHENDO MATERIAIS COMPLEMENTARES

# %%
df_complemento = df_materiais[~df_materiais['DESCRICAO_CLASSE'].isin(id_classe)]
df_complemento
# Out:
#         Unnamed: 0  ID_MATERIAL TIPO  CODIGO_MATERIAL ITEM_SUSPENSO  \
# 0                0       431550    M           600581             N
# 1                1       431551    M           600580             N
# 2                2       431552    M           600579             N
# 3                3       431553    M           600578             N
# 4                4       431554    M           600576             N
# ...            ...          ...  ...              ...           ...
# 253861      253861       683446    M           377520             S
# 253862      253862       683447    M           377519             S
# 253863      253863       683780    M           612103             N
# 253864      253864       683781    M           229763             N
# 253865      253865       685185    M           332382             N
#
#        MATERIAL_SUSTENTAVEL  CODIGO_CLASSE  \
# 0                         N           5905
# 1                         N           5905
# ...

# %%
contagem_material_complemento = df_complemento['NOME_MATERIAL'].value_counts()

# Obter os materiais com contagem entre 5 e 50
materiais_com_contagem_entre_5_e_50 = contagem_material_complemento[(contagem_material_complemento >= 5) & (contagem_material_complemento <= 50)].index

# Filtrar o DataFrame para incluir apenas as linhas onde 'material' está na lista de materiais com contagem entre 5 e 50
df_filtrado_complemento = df_complemento[df_complemento['NOME_MATERIAL'].isin(materiais_com_contagem_entre_5_e_50)]

# Exibir o DataFrame filtrado
df_filtrado_complemento
# Out:
#         Unnamed: 0  ID_MATERIAL TIPO  CODIGO_MATERIAL ITEM_SUSPENSO  \
# 1789          1789       433339    M           268043             N
# 1790          1790       433340    M           250194             N
# 1791          1791       433341    M           233932             N
# 1792          1792       433342    M           204534             N
# 1793          1793       433343    M           204522             N
# ...            ...          ...  ...              ...           ...
# 253849      253849       682069    M           483366             N
# 253850      253850       682070    M           483365             N
# 253851      253851       682071    M           483364             N
# 253852      253852       682072    M           483363             N
# 253853      253853       682073    M           483362             N
#
#        MATERIAL_SUSTENTAVEL  CODIGO_CLASSE  \
# 1789                      N           7510
# 1790                      N           7510
# ...

# %%
df_filtrado_complemento.drop_duplicates(['DESCRICAO_CLASSE'], inplace=True)
# Out:
# /tmp/ipykernel_7285/2258860908.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_filtrado_complemento.drop_duplicates(['DESCRICAO_CLASSE'], inplace=True)

# %%
df_mat_compl = df_filtrado_complemento.sample(31)
df_mat_compl
# Out:
#         Unnamed: 0  ID_MATERIAL TIPO  CODIGO_MATERIAL ITEM_SUSPENSO  \
# 77266        77266       508072    M             1201             S
# 44449        44449       475691    M           399887             N
# 73389        73389       504231    M           600279             N
# 18987        18987       450471    M           607746             N
# 160137      160137       589564    M           609732             N
# 60926        60926       491953    M           605540             N
# 57100        57100       488222    M           486666             N
# 10186        10186       441718    M           448742             N
# 45372        45372       476607    M           451173             N
# 16274        16274       447780    M           487331             N
# 130014      130014       559998    M           478565             N
# 93141        93141       523704    M           610028             N
# 22365        22365       453791    M           461984             N
# ...

# %%
len(id_mat_df)
df_mat_compl
result_resample = pd.concat([id_mat_df, df_mat_compl])
result_resample
result_resample['NOME_MATERIAL'].value_counts()
# Out:
# NOME_MATERIAL
# Bandeja Revelação                           1
# Gás Refrigeração                            1
# Despolpadeira Frutas                        1
# Lâmina Limpeza Máquina Copiadora            1
# Mangueira Radiador Veículo Automotivo       1
# Chumbo                                      1
# Bisturi Descartável                         1
# Polvaroma                                   1
# Tenda Inflável                              1
# Baú Ferramentas                             1
# Calibrador Radiação                         1
# Forro Gesso                                 1
# Anodo                                       1
# Forno Mufla                                 1
# Tira Reagente                               1
# Disquete                                    1
# "Doce Leite"                                1
# Bujão Óleo Abastecimento                    1
# Folheto Nao Tecnico                         1
# Tesoura Costura                             1
# ...

# %%
result_resample['NOME_MATERIAL'].value_counts()
cod_m = result_resample['NOME_MATERIAL']
result_resample.to_csv('result_resample.csv')

# %%
for i in cod_m:
    tam = df_materiais[df_materiais['NOME_MATERIAL'] == i]
    print(i, len(tam))
# Out:
# Bandeja Revelação 9
# Forno Mufla 17
# Retificador Soldagem 6
# Máquina Solda Portátil 30
# Empilhadeira Elétrica 19
# Serra Portátil 23
# Estação Solda 21
# Alvo De Tiro 35
# Bebida Alcoólica 26
# Êmbolo Válvula Hidráulica 7
# Grafite 27
# Lanterna Não Elétrica 47
# Moto-Esmeril 18
# Retroescavadeira 10
# Disco Liga Mista Metais 6
# Filtro Óleo 24
# Barreira Contenção / Absorvente 22
# Equipamento / Acessório - Apicultura 49
# Óleo Combustível 6
# Bloco 5
# Adubo Animal 7
# Bandeira Sinalização 6
# Escrivaninha 23
# Terminal Bateria 11
# Acessório/Componente Elétrico Eletrônico 31
# Detector Metais 16
# Tubo Porta-Documento 32
# Despolpadeira Frutas 6
# Lâmina Limpeza Máquina Copiadora 35
# Mangueira Radiador Veículo Automotivo 34
# Chumbo 16
# Bisturi Descartável 43
# Polvaroma 5
# Tenda Inflável 5
# Baú Ferramentas 5
# Calibrador Radiação 6
# Forro Gesso 13
# Gás Refrigeração 19
# Anodo 8
# Tira Reagente 44
# Disquete 27
# "Doce Leite" 14
# Bujão Óleo Abastecimento 6
# ...

# %%
df_sample_build_novo = df_materiais[~df_materiais['DESCRICAO_GRUPO']]

# %%
a_retirar = teseteee['NOME_MATERIAL'].value_counts()
a_retirar
df_filtra_retirarado = teseteee[~teseteee['material'].isin(materiais_com_contagem_maior_que_80)]

# %%
from elasticsearch import helpers

# nltk.download("punkt")

from elasticsearch import Elasticsearch

# %%
es = Elasticsearch(
    "http://localhost:9200",
    request_timeout=999999999,
)

es.info()
# Out:
# ObjectApiResponse({'name': 'melquicarvalho', 'cluster_name': 'elasticsearch', 'cluster_uuid': 'VxyIZW2KQg-9GWvUtR9Qsw', 'version': {'number': '8.12.2', 'build_flavor': 'default', 'build_type': 'deb', 'build_hash': '48a287ab9497e852de30327444b0809e55d46466', 'build_date': '2024-02-19T10:04:32.774273190Z', 'build_snapshot': False, 'lucene_version': '9.9.2', 'minimum_wire_compatibility_version': '7.17.0', 'minimum_index_compatibility_version': '7.0.0'}, 'tagline': 'You Know, for Search'})

# %%
query = {
    "query": {
        "match": {
            "material_text": "Bandeja Revelação"
        }
    },
    "size": 16,
}

# query["query"]["match"]["_score"] = {"boost": 5}

resp = es.search(index="lexmt_tip", body=query)
print("Got %d Hits:" % resp['hits']['total']['value'])
for hit in resp['hits']['hits']:
    print(hit["_source"]['material_text'])
    print(hit["_source"]['nome_material'])
    print(hit["_source"]['id_material'])
    print("-----------------")
# Out:
# Got 1161 Hits:
# Bandeja Revelação Material Plástico Altura 10CM Comprimento 15MICRA Largura 10CM Características Adicionais Com Tampa E Carretel
# Bandeja Revelação
# 475494
# -----------------
# Bandeja Revelação Material Plástico Altura 10CM Características Adicionais Ranhuras Fundo E Apoio Para Termômetro Comprimento 50CPS Largura 40X Cor Verde
# Bandeja Revelação
# 475498
# -----------------
# Bandeja Revelação Material Plástico Altura 10CM Comprimento 60MM Largura 50CPS Cor Branca Características Adicionais Ranhuras Fundo E Apoio Para Termômetro
# Bandeja Revelação
# 475495
# -----------------
# Bandeja Revelação Material Plástico Altura 10CM Cor Branca Características Adicionais Ranhuras Fundo E Apoio Para Termômetro Comprimento 40X Largura 30HP
# Bandeja Revelação
# 475496
# -----------------
# Bandeja Revelação Material Plástico Altura 10CM Comprimento 60MM Largura 50CPS Características Adicionais Ranhuras Fundo E Apoio Para Termômetro Cor Vermelha
# Bandeja Revelação
# ...

# %%
497934, 497935, 497936, 497937, 497938, 497939, 497940, 497942, 497943, 497944, 497945, 497946, 497947, 497948, 497949, 497950, 497951, 497952, 497953, 497954, 497955, 497956, 497957, 497958, 497959, 497960, 497961, 497962, 497963, 497964, 497965, 497966, 497967, 497968

# %%
# pd.set_option("max_rows", None)
pd.set_option('display.max_colwidth', None)

# %%
index_nome_ag = df_index_catmat[df_index_catmat['MATERIAL_TEXT'].str.contains('Nome Agenda')][['ID_MATERIAL']]
index_nome_ag = index_nome_ag['ID_MATERIAL'].tolist()
index_nome_ag
# Out:
# [438436,
#  438437,
#  444389,
#  444497,
#  444509,
#  444648,
#  451170,
#  451383,
#  451384,
#  458413,
#  458729,
#  475059,
#  477870,
#  480790,
#  480793,
#  480796,
#  480797,
#  480800,
#  482110,
#  482111,
#  491428,
#  491431,
#  491432,
#  491435,
#  491439,
#  491452,
#  491457,
#  491458,
#  491460,
#  491466,
#  491468,
#  491472,
#  491481,
#  491485,
#  491489,
#  491491,
#  491496,
#  491508,
#  491513,
#  491520,
#  491529,
#  491532,
#  491536,
#  491538,
#  491545,
#  491547,
#  491553,
#  491555,
#  491587,
#  491590,
#  491593,
#  491599,
#  491605,
#  491609,
#  491612,
#  491615,
#  491616,
#  491617,
#  491618,
#  491622,
#  491623,
#  491624,
#  491626,
#  491630,
#  491633,
#  491638,
#  491641,
#  491645,
#  491647,
#  491650,
#  491651,
#  491652,
#  491653,
#  491669,
#  491670,
#  491685,
#  491797,
#  491924,
#  491947,
#  491948,
#  491949,
#  491951,
#  491952,
#  491982,
#  491987,
#  491990,
#  491992,
#  491993,
#  491994,
#  491995,
# ...

# %%
len(df_index_catmat)
# Out:
# 253816

# %%
df_index_catmat_nome_ag = df_index_catmat[~df_index_catmat['ID_MATERIAL'].isin(index_nome_ag)]
df_index_catmat_nome_ag
# Out:
#         Unnamed: 0  ID_MATERIAL TIPO  CODIGO_MATERIAL ITEM_SUSPENSO  \
# 0              0.0       431550    M         600581.0             N
# 1              1.0       431551    M         600580.0             N
# 2              2.0       431552    M         600579.0             N
# 3              3.0       431553    M         600578.0             N
# 4              4.0       431554    M         600576.0             N
# ...            ...          ...  ...              ...           ...
# 253811    253861.0       683446    M         377520.0             S
# 253812    253862.0       683447    M         377519.0             S
# 253813    253863.0       683780    M         612103.0             N
# 253814    253864.0       683781    M         229763.0             N
# 253815    253865.0       685185    M         332382.0             N
#
#        MATERIAL_SUSTENTAVEL  CODIGO_CLASSE  \
# 0                         N           5905
# 1                         N           5905
# ...

# %%
nome_ag_sampl = [581197, 508151]

# %%
df_index_catmat_nome_ag = df_index_catmat_nome_ag[~df_index_catmat_nome_ag['ID_MATERIAL'].isin(nome_ag_sampl)]
df_index_catmat_nome_ag
# Out:
#         Unnamed: 0  ID_MATERIAL TIPO  CODIGO_MATERIAL ITEM_SUSPENSO  \
# 0              0.0       431550    M         600581.0             N
# 1              1.0       431551    M         600580.0             N
# 2              2.0       431552    M         600579.0             N
# 3              3.0       431553    M         600578.0             N
# 4              4.0       431554    M         600576.0             N
# ...            ...          ...  ...              ...           ...
# 253811    253861.0       683446    M         377520.0             S
# 253812    253862.0       683447    M         377519.0             S
# 253813    253863.0       683780    M         612103.0             N
# 253814    253864.0       683781    M         229763.0             N
# 253815    253865.0       685185    M         332382.0             N
#
#        MATERIAL_SUSTENTAVEL  CODIGO_CLASSE  \
# 0                         N           5905
# 1                         N           5905
# ...

# %%
df_index_catmat_nome_ag.to_csv('df_index_catmat_resample.csv')

# %%
df_selc = df_index_catmat[df_index_catmat['ID_MATERIAL'].isin([475494, 475495, 475496, 475497, 475498, 475499, 475500, 475501])]
df_selc[['ID_MATERIAL', 'MATERIAL_TEXT']]
# Out:
#        ID_MATERIAL                                      MATERIAL_TEXT
# 44235       475494  Bandeja Revelação Material Plástico Altura 10C...
# 44236       475495  Bandeja Revelação Material Plástico Altura 10C...
# 44237       475496  Bandeja Revelação Material Plástico Altura 10C...
# 44238       475497  Bandeja Revelação Material Plástico Altura 10C...
# 44239       475498  Bandeja Revelação Material Plástico Altura 10C...
# 44240       475499  Bandeja Revelação Material Plástico Altura 10C...
# 44241       475500  Bandeja Revelação Material Plástico Cor Branca...
# 44242       475501  Bandeja Revelação Material Plástico Cor Branca...

# %%
# 633259    Bandeja Revelação Material Plástico Características Adicionais Ranhuras Fundo E Apoio Para Termômetro Altura 7L/MIN Comprimento 18POL Largura 13 Cor Bege
df_selc = df_index_catmat[df_index_catmat['ID_MATERIAL'].isin([475494, 475495, 475496, 475497, 475498, 475499, 475500, 475501])]
df_selc['MATERIAL_TEXT']
#Bandeja Revelação Plástico Ranhuras Fundo E Apoio Para Termômetro Altura 7L/MIN Comprimento 18POL Largura 13 Cor Bege
# print(df_selc['NOME_MATERIAL'])
# Out:
# 44235                                    Bandeja Revelação Material Plástico Altura 10CM Comprimento 15MICRA Largura 10CM Características Adicionais Com Tampa E Carretel
# 44236         Bandeja Revelação Material Plástico Altura 10CM Comprimento 60MM Largura 50CPS Cor Branca Características Adicionais Ranhuras Fundo E Apoio Para Termômetro
# 44237           Bandeja Revelação Material Plástico Altura 10CM Cor Branca Características Adicionais Ranhuras Fundo E Apoio Para Termômetro Comprimento 40X Largura 30HP
# 44238       Bandeja Revelação Material Plástico Altura 10CM Comprimento 60MM Largura 50CPS Características Adicionais Ranhuras Fundo E Apoio Para Termômetro Cor Vermelha
# 44239           Bandeja Revelação Material Plástico Altura 10CM Características Adicionais Ranhuras Fundo E Apoio Para Termômetro Comprimento 50CPS Largura 40X Cor Verde
# ...

# %%
df_selc = df_index_catmat[df_index_catmat['ID_MATERIAL'].isin([476636])]
df_selc['MATERIAL_TEXT']
# Out:
# 45385    Retificador Soldagem Alimentação 220/380/440VCA Freqüência 60MM Características Adicionais Soldagem Eletrodos Até 6 Mm Diâmetro Corrente 300L Peso 215MM
# Name: MATERIAL_TEXT, dtype: object

# %%
pd.set_option('display.max_colwidth', 1000)

# %%
index_nome_ag = df_index_catmat[df_index_catmat['MATERIAL_TEXT'].str.contains('Retroescavadeira')][['ID_MATERIAL', 'NOME_MATERIAL', 'MATERIAL_TEXT']]
index_nome_ag
# Out:
#         ID_MATERIAL                           NOME_MATERIAL  \
# 32388        463732                          Câmara Ar Pneu
# 32389        463733                          Câmara Ar Pneu
# 52760        483928                               Filtro Ar
# 52761        483929                               Filtro Ar
# 75710        506553                      Bateria Automotiva
# 113965       544222                      Filtro Combustível
# 114171       682380                      Filtro Combustível
# 114179       682388                      Filtro Combustível
# 114214       544437                  Filtro Óleo Hidráulico
# 114233       544456                  Filtro Óleo Hidráulico
# 114240       683005                  Filtro Óleo Hidráulico
# 114241       683006                  Filtro Óleo Hidráulico
# 114251       683016                  Filtro Óleo Hidráulico
# 114252       683017                  Filtro Óleo Hidráulico
# 150941       580611                     Reparo Bomba D'Agua
# ...
